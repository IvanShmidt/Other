# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.metrics import *
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
os.path.isfile(path + '/' + f + '/' + sf)
# Out:
# True

# %%
path = './Data'
dfs = {}

files = os.listdir(path)
for f in files:
    _path = path + '/' + f
    if os.path.isfile(_path):
        dfs[_path] = pd.read_csv(_path)
    else:
        subfiles = os.listdir(_path)
        for sf in subfiles:
            _path = path + '/' + f + '/' + sf
            if os.path.isfile(_path):
                dfs[_path] = pd.read_csv(_path)
                
del dfs['./Data/wordPressNormalandAttack/NormalV1.1.csv']  # данные с сайта wordpress,
                                                           # они нам не нужны дл обучения

# %%
# df = pd.concat([i[1] for i in dfs.items()])
# df = shuffle(df)
print('Признаки:\n', ', '.join(df.columns))
df.head()
# Out:
# Признаки:
#  Row, udp, select, bin, run, poll, media, sys, dev, etc, usr, root, host, brk, boot, mkdir, write, connect, tcp, clone_API, proc, read, var, network_http, File_IO, kill_API, accept, home, munmap, mnt, opt, rename, srv, mmap, chdir_API, network_connection, execve_API, Normal, Attack
#       Row  udp  select  bin  run  poll  media  sys  dev   etc   ...    mnt  \
# 657     0    0      46    0    0   380      0    0    9  1365   ...      0
# 894     0    0     569    0    0    17      0    0    0     0   ...      0
# 1251    0    0       1    0    0  8897      0    0    0   922   ...      0
# 1546    0    0      18    0    0     0      0    0    0     0   ...      0
# 2116    0    0      20    0    0     0      0    0    0     0   ...      0
#
#       opt  rename  srv  mmap  chdir_API  network_connection  execve_API  \
# 657     0       0    0  1146        120                4847          84
# 894     0       0    0     0          0                  30           0
# 1251    0       0    0     0        463               16232           0
# 1546    0       0    0     0          0                   0           0
# 2116    0       0    0     0          0                   0           0
#
#       Normal  Attack
# 657        0       1
# 894        0       1
# 1251       1       0
# 1546       0       1
# 2116       0       1
#
# [5 rows x 39 columns]

# %%
# данные несбалансированны
df.Attack.value_counts(normalize=True)
# Out:
# 1    0.718122
# 0    0.281878
# Name: Attack, dtype: float64

# %%
X, y = df.drop(['Normal', 'Attack'], axis=1), df.Attack

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# %%
# %%time

svm = SVC()
lg  = LogisticRegression()
knn = KNeighborsClassifier()
gbc = GradientBoostingClassifier()

for clf in [lg, knn, gbc]:
    clf.fit(X_train, y_train)
    print('\n\n', clf.__class__.__name__)
    print(classification_report(y_test, clf.predict(X_test)))
    print(confusion_matrix(y_test, clf.predict(X_test), labels=[0, 1]))
# Out:
#  LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83      2764
#            1       0.91      0.97      0.94      6944
#
#    micro avg       0.91      0.91      0.91      9708
#    macro avg       0.91      0.87      0.89      9708
# weighted avg       0.91      0.91      0.91      9708
#
# [[2102  662]
#  [ 195 6749]]
#
#
#  KNeighborsClassifier
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2764
#            1       1.00      1.00      1.00      6944
#
#    micro avg       1.00      1.00      1.00      9708
#    macro avg       0.99      0.99      0.99      9708
# weighted avg       1.00      1.00      1.00      9708
#
# [[2732   32]
#  [  16 6928]]
#
#
#  GradientBoostingClassifier
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2764
#            1       1.00      1.00      1.00      6944
#
#    micro avg       1.00      1.00      1.00      9708
#    macro avg       1.00      0.99      1.00      9708
# weighted avg       1.00      1.00      1.00      9708
#
# [[2736   28]
#  [   6 6938]]
# CPU times: user 4.66 s, sys: 615 ms, total: 5.28 s
# Wall time: 4.11 s

# %%
sns.set(font_scale=1)
sns.set_style("white")
fig = plt.figure(figsize=(8, 6))
ax = plt.axes()

feat_imp = pd.Series(gbc.feature_importances_, X_train.columns).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Характеристика важности признаков')
plt.xticks(rotation=90)
plt.ylabel('Важность признаков')
plt.show()

#plt.savefig('plot_feat_importance.png', bbox_inches = 'tight')

# %%
from sklearn.manifold import TSNE

# %%
# %%time
tsne = TSNE(random_state=17)
X_tsne = tsne.fit_transform(X)

plt.figure(figsize=(8, 7))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], s = 3.5, c=y, cmap='Spectral')
plt.title('t-SNE проекция в двумерное пространство')

# plt.savefig('tsne_plot.png')
plt.show()
# Out:
# Wall time: 909 ms

# %% [markdown]
# Данные разбиты на кластеры, соотв разным типам атак. Для нас главное, что нормальное поведение тоже относительно неплохо группируется в отд кластеры <br/><br/>

# %% [markdown]
# <br/>Пробуем обучиться только на признаках, соответствующих syscalls, смотрим, как изменится качество

# %%
syscalls_ftrs = ['read', 'File_IO', 'write', 'accept', 'network_http', 'clone_API', 'select', 'poll', \
                 'rename', 'chdir_API', 'kill_API', 'mkdir', 'brk', 'mmap', 'munmap']

X_train, X_test, y_train, y_test = \
        train_test_split(df[syscalls_ftrs].values, df.Attack,test_size=0.3, random_state=17)

gbc = GradientBoostingClassifier()
gbc.fit(X_train, y_train)

print(classification_report(y_test, gbc.predict(X_test)))
print(confusion_matrix(y_test, gbc.predict(X_test), labels=[0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2764
#            1       0.99      1.00      1.00      6944
#
#    micro avg       0.99      0.99      0.99      9708
#    macro avg       0.99      0.99      0.99      9708
# weighted avg       0.99      0.99      0.99      9708
#
# [[2728   36]
#  [  26 6918]]

# %% [markdown]
# Качество упало на 1%, что несущественно.<br/>
# Результаты соответствуют полученным авторами статьи

# %% [markdown]
# ### Работа с аномалиями

# %% [markdown]
# Поскольку реальные атаки могут отличаться от тех, которые попали в тренировочную выборку, возникла идея решит задачу поиска аномалий, <br/> т.е. взять примеры нормального поведения, обучить на них соотв. алгоритмы и посмотреть, насколько хорошо они детектируют аномалии (примеры атак) <br/>
# Использовалось два подхода:<br/>
#   + Novelty detection (считаем примеры в обучающей выборке неаномальными, смотрим, насколько на них непохожи все остальные)
#   + Outlier detection (находим, где сконцентрированы примеры из обучающей выборки, далеко расположенные примеры считаем выбросами, в том числе из трейна)

# %%
# Разбиваем датасет на два, с нормальным поведением и аномалиями
# Также датасет с нормальным поведением разбиваем на трейн и тест

df_norm = df[df.Normal == 1].drop(['Normal', 'Attack'], axis=1)
df_atck = df[df.Attack == 1].drop(['Normal', 'Attack'], axis=1)

assert(len(df_norm) + len(df_atck) == len(df))

test_size=0.3
idx = int(len(df_norm)*(1 - test_size))
X_train, X_test = df_norm.iloc[:idx], df_norm.iloc[idx:]

# %% [markdown]
# Ниже ошибка алг на трейне, тесте и на датасете с аномалиями <br/>
# Ошибку считаю, как долю соответствующих неправильных ответов

# %% [markdown]
# #### Novelty detection

# %%
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor

svm = OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.1, novelty=True)

for clf in [svm, lof]:
    
    clf.fit(X_train)

    y_pred_train = clf.predict(X_train)
    y_pred_test = clf.predict(X_test)
    y_pred_outliers = clf.predict(df_atck)

    errors = {}
    errors['n_error_train'] = y_pred_train[y_pred_train == -1].size / len(y_pred_train)
    errors['n_error_test'] = y_pred_test[y_pred_test == -1].size / len(y_pred_test)
    errors['n_error_outliers'] = y_pred_outliers[y_pred_outliers == 1].size / len(y_pred_outliers)

    print(F"\n{clf.__class__.__name__}")
    for name, e in errors.items():
        print(f"{name:17}: {round(e, 4)}")
# Out:
# OneClassSVM
# n_error_train    : 0.502
# n_error_test     : 0.817
# n_error_outliers : 0.0207
#
# LocalOutlierFactor
# n_error_train    : 0.0882
# n_error_test     : 0.0972
# n_error_outliers : 0.1482

# %% [markdown]
# #### Outlier detection

# %%
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope

ifor = IsolationForest(max_samples=100, random_state=17)
eenv = EllipticEnvelope(random_state=17)

for clf in [ifor, eenv]:
    
    clf.fit(X_train)

    y_pred_train = clf.predict(X_train)
    y_pred_test = clf.predict(X_test)
    y_pred_outliers = clf.predict(df_atck)

    errors = {}
    errors['n_error_train'] = y_pred_train[y_pred_train == -1].size / len(y_pred_train)
    errors['n_error_test'] = y_pred_test[y_pred_test == -1].size / len(y_pred_test)
    errors['n_error_outliers'] = y_pred_outliers[y_pred_outliers == 1].size / len(y_pred_outliers)

    print(F"\n{clf.__class__.__name__}")
    for name, e in errors.items():
        print(f"{name:17}: {round(e, 4)}")
# Out:
# IsolationForest
# n_error_train    : 0.1001
# n_error_test     : 0.1052
# n_error_outliers : 0.4266
#
# EllipticEnvelope
# n_error_train    : 0.1001
# n_error_test     : 0.1008
# n_error_outliers : 0.9826

# %% [markdown]
# <br/>Лучшее качество у **LocalOutlierFactor**<br/>
# Посмотрим, как зависит его качеcтво от параметров

# %%
contamination = [i/10 for i in range(1, 6)]
n_neighbors   = [i for i in range(20, 100, 20)]

for c, n in product(contamination, n_neighbors):
    clf = LocalOutlierFactor(n_neighbors=n, contamination=c, novelty=True)
    clf.fit(X_train)

    y_pred_train = clf.predict(X_train)
    y_pred_test = clf.predict(X_test)
    y_pred_outliers = clf.predict(df_atck)

    errors = {}
    errors['n_error_train'] = y_pred_train[y_pred_train == -1].size / len(y_pred_train)
    errors['n_error_test'] = y_pred_test[y_pred_test == -1].size / len(y_pred_test)
    errors['n_error_outliers'] = y_pred_outliers[y_pred_outliers == 1].size / len(y_pred_outliers)

    print(F"\n{clf.__class__.__name__} n_neighbors={n}, contamination={c}")
    for name, e in errors.items():
        print(f"{name:17}: {round(e, 4)}")
# Out:
# LocalOutlierFactor n_neighbors=20, contamination=0.1
# n_error_train    : 0.0882
# n_error_test     : 0.0972
# n_error_outliers : 0.1482
#
# LocalOutlierFactor n_neighbors=40, contamination=0.1
# n_error_train    : 0.0927
# n_error_test     : 0.1081
# n_error_outliers : 0.1595
#
# LocalOutlierFactor n_neighbors=60, contamination=0.1
# n_error_train    : 0.0982
# n_error_test     : 0.1012
# n_error_outliers : 0.1624
#
# LocalOutlierFactor n_neighbors=80, contamination=0.1
# n_error_train    : 0.0952
# n_error_test     : 0.0932
# n_error_outliers : 0.1658
#
# LocalOutlierFactor n_neighbors=20, contamination=0.2
# n_error_train    : 0.1837
# n_error_test     : 0.213
# n_error_outliers : 0.103
#
# LocalOutlierFactor n_neighbors=40, contamination=0.2
# n_error_train    : 0.1913
# n_error_test     : 0.2152
# n_error_outliers : 0.146
#
# LocalOutlierFactor n_neighbors=60, contamination=0.2
# n_error_train    : 0.1928
# n_error_test     : 0.2053
# n_error_outliers : 0.153
#
# LocalOutlierFactor n_neighbors=80, contamination=0.2
# n_error_train    : 0.1972
# n_error_test     : 0.2141
# n_error_outliers : 0.1456
#
# LocalOutlierFactor n_neighbors=20, contamination=0.3
# n_error_train    : 0.278
# n_error_test     : 0.3263
# n_error_outliers : 0.0976
#
# LocalOutlierFactor n_neighbors=40, contamination=0.3
# n_error_train    : 0.2878
# n_error_test     : 0.3244
# n_error_outliers : 0.1239
#
# LocalOutlierFactor n_neighbors=60, contamination=0.3
# n_error_train    : 0.2942
# n_error_test     : 0.3237
# n_error_outliers : 0.1415
#
# LocalOutlierFactor n_neighbors=80, contamination=0.3
# n_error_train    : 0.2935
# n_error_test     : 0.3233
# n_error_outliers : 0.142
#
# LocalOutlierFactor n_neighbors=20, contamination=0.4
# n_error_train    : 0.3712
# n_error_test     : 0.4227
# n_error_outliers : 0.0953
#
# LocalOutlierFactor n_neighbors=40, contamination=0.4
# n_error_train    : 0.3857
# n_error_test     : 0.422
# n_error_outliers : 0.0601
#
# LocalOutlierFactor n_neighbors=60, contamination=0.4
# n_error_train    : 0.3922
# n_error_test     : 0.4326
# n_error_outliers : 0.1308
#
# LocalOutlierFactor n_neighbors=80, contamination=0.4
# n_error_train    : 0.3957
# n_error_test     : 0.4253
# n_error_outliers : 0.1304
#
# LocalOutlierFactor n_neighbors=20, contamination=0.5
# n_error_train    : 0.4759
# n_error_test     : 0.5283
# n_error_outliers : 0.0816
#
# LocalOutlierFactor n_neighbors=40, contamination=0.5
# n_error_train    : 0.4908
# n_error_test     : 0.5338
# n_error_outliers : 0.0297
#
# LocalOutlierFactor n_neighbors=60, contamination=0.5
# n_error_train    : 0.4908
# n_error_test     : 0.5294
# n_error_outliers : 0.0299
#
# LocalOutlierFactor n_neighbors=80, contamination=0.5
# n_error_train    : 0.4919
# n_error_test     : 0.5192
# n_error_outliers : 0.1039

# %% [markdown]
# Можно понизить ошибку распознавания аномальных поведения за счёт увеличения ошибки на нормальном поведении и наоборот. <br/> Поэтому конкретные параметры лучше выбирать в зависимости от бизнес логикитого, что нам важнее <br/>
# В целом, можно добиться ошибки в 15% на выявлении аномалий при ошибке в 10% на нормальном поведении
