# %%
from bitstring import BitArray
from PIL import Image
import numpy as np

# %%
# #def bitstring_to_bytes(s):
# #    return int(s, 2).to_bytes(len(s) // 8, byteorder='big')

# ENCODING = 'utf-8'
# st = "Ваняпривет"

# enc_str = bytearray(st, encoding=ENCODING)
# _enc_st = ''.join(format(x, 'b') for x in bytearray(st, encoding=ENCODING))

# print(enc_str)
# print(_enc_st)

# print('уже результат: ', str(BitArray(bin=_enc_st).tobytes(), ENCODING))
# BitArray(bin=_enc_st)

# %%
ENCODING = 'utf-8'
st = "Привет. ! Меня зову Ваня. Попрограммируем?"

enc_str = bytearray(st, encoding=ENCODING)

#print(enc_str)

ba = BitArray(bytes=enc_str)
print(ba.bin)

ab = BitArray(bin=ba.bin)
print(ab.tobytes().decode(ENCODING))
# Out:
# ...
# Привет. ! Меня зову Ваня. Попрограммируем?

# %%
ENCODING = 'utf-8'
st = "Привет. Я хочу кушать. пойдем поедим, дружище!!!"

original = Image.open('container.png')
width, height = original.size

enc_str = bytearray(st, encoding=ENCODING)

b_arr = BitArray(bytes=enc_str)
#print(b_arr.bin)

ab = BitArray(bin=b_arr.bin)
#print(ab.tobytes().decode(ENCODING))

# %%
rest_spaces = (width*height - len(b_arr.bin))/8
st += int(rest_spaces) * " "

# %%
width*height == len(BitArray(bytes=bytearray(st, encoding=ENCODING)).bin)
# Out:
# True

# %%
# ENCRIPTION

ENCODING = 'utf-8'
st = "Привет. Я пошел!!!"

enc_str = bytearray(st, encoding=ENCODING)
rest_spaces = (width*height - len(BitArray(bytes=enc_str).bin)) / 8
st += int(rest_spaces) * " "
b_arr = bytearray(st, encoding=ENCODING)
bits_str = BitArray(bytes=b_arr).bin
bits_arr = [int(i) for i in bits_str]

original = Image.open('container.png')
width, height = original.size

if width*height == len(bits_arr):
    print('size matched.')

steg = Image.new('RGB', (width, height))

idx = 0
for i in range(width):
    for j in range(height):
        r, g, b = original.getpixel((i, j))
        if bits_arr[idx] == 0:
            r &= 254
        else:
            r |= 1
        steg.putpixel((i, j), (r, g, b))
        idx += 1
        
print('saving')
steg.save('encripted.png')
# Out:
# size matched.
# saving

# %%
# DECRIPTION

container = Image.open('encripted.png')
width, height = container.size

bits_arr = []

for i in range(width):
    for j in range(height):
        r, g, b = container.getpixel((i, j))
        if r & 1 == 1:
            bits_arr.append(1) 
        else:
            bits_arr.append(0)
            
bits_str = ''.join(str(i) for i in bits_arr)
print(width*height == len(bits_arr), len(bits_arr))
b_arr = BitArray(bin = bits_str).tobytes()
print(b_arr.decode(ENCODING))
# Out:
# True 2073600
# Привет. Я пошел!!!

# %%
# for i, e in enumerate(_bits_str):
#     if e != bits_arr[i]:
#         print('!', end = ' ')

_bits_str[:10]
# Out:
# '1101000010'

# %%
[int(i) for i in bits_arr[:10]]
# Out:
# [1, 1, 0, 1, 0, 0, 0, 0, 1, 0]

# %%
# ENCODING = 'cp1251'
# st = "lala"

# enc_str = bytearray(st, encoding=ENCODING)
# _enc_st = ''.join(format(x, 'b') for x in bytearray(st, encoding=ENCODING))

# print(enc_str)
# print(_enc_st)

# print('уже результат: ', str(BitArray(bin=_enc_st).tobytes(), ENCODING))
# BitArray(bin=_enc_st)

# %%
def random_ints_with_sum_and_length(n, _len):
    # n -верхняя граница, можем брать только числа, которые в сумме будут меньше n
    # _len - минимальная длина массива на выходе, т.е. количество наших бит, которые нежно закодировать
    
    def random_ints_with_sum(n, seed):
        """
        Generate non-negative random integers summing to n.
        """
        random_gen = np.random.RandomState(seed)
        while n > 1:
            r = random_gen.randint(1, n)
            yield r
            n -= r
            
    seed = 1
    ints = list(random_ints_with_sum(n, seed))
    
    while len(ints) < _len:
        seed += np.random.randint(1, 10)
        ints = list(random_ints_with_sum(n, seed))
        
    return ints, seed

# %%
# ints, seed = random_ints_with_sum_and_length(100, 10)
# print(len(ints), seed)
# print(ints)

random_gen = np.random.RandomState(17)
a = random_gen.choice(100, 5, replace=False)
np.sort(a)
# Out:
# array([ 4,  9, 28, 71, 73])

# %%
# ENCRIPTION S_LSB

ENCODING = 'utf-8'
st = "Пока. Я пошел!!!"

#enc_str = bytearray(st, encoding=ENCODING)
# rest_spaces = (width*height - len(BitArray(bytes=enc_str).bin)) / 8
# st += int(rest_spaces) * " "
# st = enc_str
b_arr = bytearray(st, encoding=ENCODING)
bits_str = BitArray(bytes=b_arr).bin
bits_arr = [int(i) for i in bits_str]

print('len bits_arr: {}'.format(len(bits_arr)))

original = Image.open('container.png')
width, height = original.size

random_gen    = np.random.RandomState(17)
width_offset  = random_gen.choice(width, len(bits_arr), replace=False)
height_offset = random_gen.choice(height, len(bits_arr), replace=False)

print('offsets equal: {}'.format(len(width_offset) == len(height_offset)))
print('{}, w: {}'.format(width, width_offset[:10]))
print('{} h: {}'.format(height, height_offset[:10]))
# if width*height == len(bits_arr):
#     print('size matched.')

steg = Image.new('RGB', (width, height))

idx = 0
for i in range(len(bits_arr)):
    w, h = int(width_offset[i]), int(height_offset[i])
    r, g, b = original.getpixel((w, h))
    if bits_arr[idx] == 0:
        r &= 254
    else:
        r |= 1
    steg.putpixel((width_offset[i], height_offset[i]), (r, g, b))
    idx += 1
    
print('saving')
steg.save('encripted.png')
# Out:
# len bits_arr: 208
# offsets equal: True
# 1920, w: [ 687 1790 1064 1656 1126  763   47  606  203 1635]
# 1080 h: [439 590 506  48 810  26  47 500 763 456]
# saving

# %%
# DECRIPTION S_LSB

seed = int(input('seed: '))
arr_len = int(input('arr_len: '))

container = Image.open('encripted.png')
width, height = container.size


random_gen    = np.random.RandomState(seed)
width_offset  = random_gen.choice(width, arr_len, replace=False)
height_offset = random_gen.choice(height, arr_len, replace=False)

bits_arr = []

print('offsets equal: {}'.format(len(width_offset) == len(height_offset)))
print('{}, w: {}'.format(width, width_offset[:10]))
print('{} h: {}'.format(height, height_offset[:10]))

for i in range(arr_len):
    w, h = int(width_offset[i]), int(height_offset[i])
    r, g, b = container.getpixel((w, h))
    if r & 1 == 1:
        bits_arr.append(1) 
    else:
        bits_arr.append(0)

# for i in range(width):
#     for j in range(height):
#         r, g, b = container.getpixel((i, j))
#         if r & 1 == 1:
#             bits_arr.append(1) 
#         else:
#             bits_arr.append(0)
            
print('len bits_arr: {}'.format(len(bits_arr)))
    
    
bits_str = ''.join(str(i) for i in bits_arr)
#print(width*height == len(bits_arr), len(bits_arr))
b_arr = BitArray(bin = bits_str).tobytes()
print(b_arr.decode(ENCODING))
# Out:
# seed: 17
# arr_len: 240
# offsets equal: True
# 1920, w: [ 687 1790 1064 1656 1126  763   47  606  203 1635]
# 1080 h: [439 590 506  48 810  26  47 500 763 456]
# len bits_arr: 240
# Пока. Я пошел!!!

# %%
import base64

# %%
s = base64.b64encode(bytearray('lalaLand', encoding=ENCODING))

# %%
base64.b64decode(s)
# Out:
# b'lalaLand'

# %%
bytearray('lalaLand', encoding=ENCODING)
# Out:
# bytearray(b'lalaLand')

# %%
s
# Out:
# b'bGFsYUxhbmQ='
